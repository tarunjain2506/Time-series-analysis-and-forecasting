# %% [markdown]
# <a class="anchor" id="0"></a>
# # Air Quality City - for Vinnytsia city - Data Mapping
#
# # Datasets:
# * [Air Quality Monitoring from EcoCity](https://www.kaggle.com/vbmokin/air-quality-monitoring-from-ecocity)
# * [Air Quality Monitoring](https://www.kaggle.com/vbmokin/air-quality-monitoring)

# %% [markdown]
# ## Acknowledgements
#
# ### Notebooks:
# * [Air Quality City - Prediction & Mapping](https://www.kaggle.com/code/vbmokin/air-quality-city-prediction-mapping)
# * [Air Quality in City - 2D Analysis](https://www.kaggle.com/vbmokin/air-quality-in-city-2d-analysis)
# * [Air Quality in Region - 2D Analysis](https://www.kaggle.com/vbmokin/air-quality-in-region-2d-analysis)
# * [Data Science for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/data-science-for-tabular-data-advanced-techniques)
# * [EDA for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/eda-for-tabular-data-advanced-techniques)
#
# ### Kaggle Datasets:
# * [Air Quality Monitoring from EcoCity](https://www.kaggle.com/vbmokin/air-quality-monitoring-from-ecocity)
# * [Air Quality Monitoring](https://www.kaggle.com/vbmokin/air-quality-monitoring)
#
# ### Thanks to:
# * https://pypi.org/project/gmplot/
# * https://livecodestream.dev/post/how-to-plot-your-data-on-maps-using-python-and-folium/

# %% [markdown]
# <a class="anchor" id="0.1"></a>
# ## Table of Contents
#
# 1. [Import libraries](#1)
# 1. [Download data](#2)
#    - [Download data from SaveEcoBot](#2.1)
#    - [Download data from EcoCity](#2.2)
#    - [Data aggregation](#2.3)
# 1. [Prediction](#3)
# 1. [Mapping](#4)

# %% [markdown]
# ## 1. Import libraries<a class="anchor" id="1"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# Work with Data - the main Python libraries
import numpy as np
import pandas as pd
from scipy.interpolate import interp2d
import datetime

# For import data
import os
import json
import requests

# Visualization
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import folium

# Modeling and Prediction
from sklearn.metrics import r2_score

import warnings
warnings.simplefilter('ignore')

# %%
indicator_name = 'PM2.5' # 'PM2.5' or 'PM10'
time_interval='H' # 'H' (hour) or D' (day)
type_agg='mean' # 'mean' or 'max'

# %%
#datetime_analysis = '2021-11-16 10:00:00'
datetime_analysis = '2021-11-27 09:00:00'  # maximum value after 2021-11-16
#datetime_analysis = '2021-11-12 18:00:00'
#datetime_analysis = '2021-01-23 18:00:00'  # maximum value

# %% [markdown]
# ## 2. Download data<a class="anchor" id="2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ### 2.1 Download data from SaveEcoBot<a class="anchor" id="2.1"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# Data from SaveEcoBot
stations_about = pd.read_csv('../input/air-quality-monitoring/saveecobot_city_about_stations.csv', header=0, sep=';')
stations_about = stations_about[stations_about['locality']=='Vinnytsia city'].reset_index(drop=True)
stations_about = stations_about.fillna(-1)
stations_about
# Out:
#    id_saveecobot  id_ecocity         network        locality  \
# 0          14627       848.0        Eco-City  Vinnytsia city
# 1           4152       767.0        Eco-City  Vinnytsia city
# 2           1008        -1.0      SaveDnipro  Vinnytsia city
# 3          17796        -1.0  luftdaten.info  Vinnytsia city
# 4          15952       337.0        Eco-City  Vinnytsia city
#
#                       address  start_date                  notes      lat  \
# 0  2nd Konstantynovycha Ln, 4  14.12.2020                     -1  49.2307
# 1              Soborna St, 36  26.06.2020  Vinnytsia City Concil  49.2329
# 2            Stetsenka St, 75  25.05.2019                     -1  49.2393
# 3              Kyivs'ka St, 5  16.05.2021                     -1  49.2380
# 4    3rd Chekhova Passage, 21  23.01.2021                     -1  49.2268
#
#        lng
# 0  28.4371
# 1  28.4704
# 2  28.4799
# 3  28.4820
# 4  28.5256

# %%
stations_about['id_station'] = "SaveEcoBot_" + stations_about['id_saveecobot'].astype('str')
stations_about['id_ecocity'] = stations_about['id_ecocity'].astype('int')
stations_about.loc[stations_about['network']=='Eco-City', 'id_station'] = "EcoCity_" + stations_about['id_ecocity'].astype('int').astype('str')
stations_about
# Out:
#    id_saveecobot  id_ecocity         network        locality  \
# 0          14627         848        Eco-City  Vinnytsia city
# 1           4152         767        Eco-City  Vinnytsia city
# 2           1008          -1      SaveDnipro  Vinnytsia city
# 3          17796          -1  luftdaten.info  Vinnytsia city
# 4          15952         337        Eco-City  Vinnytsia city
#
#                       address  start_date                  notes      lat  \
# 0  2nd Konstantynovycha Ln, 4  14.12.2020                     -1  49.2307
# 1              Soborna St, 36  26.06.2020  Vinnytsia City Concil  49.2329
# 2            Stetsenka St, 75  25.05.2019                     -1  49.2393
# 3              Kyivs'ka St, 5  16.05.2021                     -1  49.2380
# 4    3rd Chekhova Passage, 21  23.01.2021                     -1  49.2268
#
#        lng        id_station
# 0  28.4371       EcoCity_848
# 1  28.4704       EcoCity_767
# 2  28.4799   SaveEcoBot_1008
# 3  28.4820  SaveEcoBot_17796
# 4  28.5256       EcoCity_337

# %%
stations_about = stations_about[['id_station', 'lat', 'lng']]
stations_about
# Out:
#          id_station      lat      lng
# 0       EcoCity_848  49.2307  28.4371
# 1       EcoCity_767  49.2329  28.4704
# 2   SaveEcoBot_1008  49.2393  28.4799
# 3  SaveEcoBot_17796  49.2380  28.4820
# 4       EcoCity_337  49.2268  28.5256

# %% [markdown]
# ### 2.2 Download data from EcoCity<a class="anchor" id="2.2"></a>
#
# [Back to Table of Contents](#0.1)

# %%
# Data from SaveEcoBot
ecocity_stations_about = pd.read_csv('../input/air-quality-monitoring-from-ecocity/ecocity_about_stations_2021.csv', header=0, sep=';')
ecocity_stations_about
# Out:
#    id_saveecobot  id_ecocity   network          locality  \
# 0        15952.0         337  Eco-City    Vinnytsia city
# 1         4238.0         650  Eco-City  Vinnytsia region
# 2         4152.0         767  Eco-City    Vinnytsia city
# 3            NaN         774  Eco-City    Vinnytsia city
# 4            NaN         790  Eco-City    Vinnytsia city
# 5        14627.0         848  Eco-City    Vinnytsia city
# 6        14855.0        1172  Eco-City  Vinnytsia region
# 7            NaN        1315  Eco-City    Vinnytsia city
# 8            NaN        1183  Eco-City    Vinnytsia city
# 9            NaN         761  Eco-City    Vinnytsia city
#
#                                              address  start_date      lat  \
# 0                           3rd Chekhova Passage, 21  23.01.2021  49.2267
# 1                                        Turbiv town  02.08.2020  49.3435
# 2                                     Soborna St, 36  26.06.2020  49.2329
# 3               Vinnytsia, Zamostyanska Street, 7/35         NaN  49.2455
# 4                   Vinnytsia, Cosmonauts Avenue, 30         NaN  49.2268
# 5                         2nd Konstantynovycha Ln, 4  14.12.2020  49.2307
# 6                                     Ivaniv village  28.12.2020  49.4838
# 7  Vinnytsia, str. Khmelnytsky shose, 95, VNTU, b...  16.11.2021  49.2330
# 8                            Vinnytsia, str. Tram, 3         NaN  49.2311
# 9                  Vinnytsia, 600th anniversary, 66V         NaN  49.2222
#
#        lng                                    notes  \
# 0  28.5259                      Oil and fat factory
# 1  28.7298                                      NaN
# 2  28.4704                    Vinnytsia City Concil
# 3  28.4936                       Transparent office
# 4  28.4194                       Transparent office
# 5  28.4371                                      NaN
# 6  28.3636                                      NaN
# 7  28.4100  Vinnytsia National Technical University
# 8  28.4371                                   Avalon
# 9  28.4242                                  Triumph
#
#                                               source
# 0  https://eco-city.org.ua/?zoom=16&lat=49.226859...
# 1  https://eco-city.org.ua/?zoom=14&lat=49.343484...
# 2  https://eco-city.org.ua/?zoom=16&lat=49.232859...
# 3  https://eco-city.org.ua/?zoom=16&lat=49.245473...
# 4  https://eco-city.org.ua/?zoom=15&lat=49.227009...
# 5  https://eco-city.org.ua/?zoom=17&lat=49.230728...
# 6  https://eco-city.org.ua/?zoom=11&lat=49.483674...
# 7  https://eco-city.org.ua/?zoom=16&lat=49.232957...
# 8                           https://eco-city.org.ua/
# 9                           https://eco-city.org.ua/

# %%
ecocity_stations_about_city = ecocity_stations_about[ecocity_stations_about['locality']=='Vinnytsia city'].reset_index(drop=True)
ecocity_stations_about_city['id_ecocity'] = ecocity_stations_about_city['id_ecocity'].astype('int')
ecocity_stations_about_city
# Out:
#    id_saveecobot  id_ecocity   network        locality  \
# 0        15952.0         337  Eco-City  Vinnytsia city
# 1         4152.0         767  Eco-City  Vinnytsia city
# 2            NaN         774  Eco-City  Vinnytsia city
# 3            NaN         790  Eco-City  Vinnytsia city
# 4        14627.0         848  Eco-City  Vinnytsia city
# 5            NaN        1315  Eco-City  Vinnytsia city
# 6            NaN        1183  Eco-City  Vinnytsia city
# 7            NaN         761  Eco-City  Vinnytsia city
#
#                                              address  start_date      lat  \
# 0                           3rd Chekhova Passage, 21  23.01.2021  49.2267
# 1                                     Soborna St, 36  26.06.2020  49.2329
# 2               Vinnytsia, Zamostyanska Street, 7/35         NaN  49.2455
# 3                   Vinnytsia, Cosmonauts Avenue, 30         NaN  49.2268
# 4                         2nd Konstantynovycha Ln, 4  14.12.2020  49.2307
# 5  Vinnytsia, str. Khmelnytsky shose, 95, VNTU, b...  16.11.2021  49.2330
# 6                            Vinnytsia, str. Tram, 3         NaN  49.2311
# 7                  Vinnytsia, 600th anniversary, 66V         NaN  49.2222
#
#        lng                                    notes  \
# 0  28.5259                      Oil and fat factory
# 1  28.4704                    Vinnytsia City Concil
# 2  28.4936                       Transparent office
# 3  28.4194                       Transparent office
# 4  28.4371                                      NaN
# 5  28.4100  Vinnytsia National Technical University
# 6  28.4371                                   Avalon
# 7  28.4242                                  Triumph
#
#                                               source
# 0  https://eco-city.org.ua/?zoom=16&lat=49.226859...
# 1  https://eco-city.org.ua/?zoom=16&lat=49.232859...
# 2  https://eco-city.org.ua/?zoom=16&lat=49.245473...
# 3  https://eco-city.org.ua/?zoom=15&lat=49.227009...
# 4  https://eco-city.org.ua/?zoom=17&lat=49.230728...
# 5  https://eco-city.org.ua/?zoom=16&lat=49.232957...
# 6                           https://eco-city.org.ua/
# 7                           https://eco-city.org.ua/

# %%
ecocity_stations_about_city['id_station'] = "EcoCity_" + ecocity_stations_about_city['id_ecocity'].astype('str')
ecocity_stations_about_city.loc[ecocity_stations_about_city['network']=='Eco-City', 'id_station'] = "EcoCity_" + ecocity_stations_about_city['id_ecocity'].astype('str')
ecocity_stations_about_city
# Out:
#    id_saveecobot  id_ecocity   network        locality  \
# 0        15952.0         337  Eco-City  Vinnytsia city
# 1         4152.0         767  Eco-City  Vinnytsia city
# 2            NaN         774  Eco-City  Vinnytsia city
# 3            NaN         790  Eco-City  Vinnytsia city
# 4        14627.0         848  Eco-City  Vinnytsia city
# 5            NaN        1315  Eco-City  Vinnytsia city
# 6            NaN        1183  Eco-City  Vinnytsia city
# 7            NaN         761  Eco-City  Vinnytsia city
#
#                                              address  start_date      lat  \
# 0                           3rd Chekhova Passage, 21  23.01.2021  49.2267
# 1                                     Soborna St, 36  26.06.2020  49.2329
# 2               Vinnytsia, Zamostyanska Street, 7/35         NaN  49.2455
# 3                   Vinnytsia, Cosmonauts Avenue, 30         NaN  49.2268
# 4                         2nd Konstantynovycha Ln, 4  14.12.2020  49.2307
# 5  Vinnytsia, str. Khmelnytsky shose, 95, VNTU, b...  16.11.2021  49.2330
# 6                            Vinnytsia, str. Tram, 3         NaN  49.2311
# 7                  Vinnytsia, 600th anniversary, 66V         NaN  49.2222
#
#        lng                                    notes  \
# 0  28.5259                      Oil and fat factory
# 1  28.4704                    Vinnytsia City Concil
# 2  28.4936                       Transparent office
# 3  28.4194                       Transparent office
# 4  28.4371                                      NaN
# 5  28.4100  Vinnytsia National Technical University
# 6  28.4371                                   Avalon
# 7  28.4242                                  Triumph
#
#                                               source    id_station
# 0  https://eco-city.org.ua/?zoom=16&lat=49.226859...   EcoCity_337
# 1  https://eco-city.org.ua/?zoom=16&lat=49.232859...   EcoCity_767
# 2  https://eco-city.org.ua/?zoom=16&lat=49.245473...   EcoCity_774
# 3  https://eco-city.org.ua/?zoom=15&lat=49.227009...   EcoCity_790
# 4  https://eco-city.org.ua/?zoom=17&lat=49.230728...   EcoCity_848
# 5  https://eco-city.org.ua/?zoom=16&lat=49.232957...  EcoCity_1315
# 6                           https://eco-city.org.ua/  EcoCity_1183
# 7                           https://eco-city.org.ua/   EcoCity_761

# %%
ecocity_stations_about_city = ecocity_stations_about_city[['id_station', 'lat', 'lng']]
ecocity_stations_about_city
# Out:
#      id_station      lat      lng
# 0   EcoCity_337  49.2267  28.5259
# 1   EcoCity_767  49.2329  28.4704
# 2   EcoCity_774  49.2455  28.4936
# 3   EcoCity_790  49.2268  28.4194
# 4   EcoCity_848  49.2307  28.4371
# 5  EcoCity_1315  49.2330  28.4100
# 6  EcoCity_1183  49.2311  28.4371
# 7   EcoCity_761  49.2222  28.4242

# %% [markdown]
# ### 2.3 Data aggregation<a class="anchor" id="2.3"></a>
#
# [Back to Table of Contents](#0.1)

# %%
ecocity_stations_about_city_list = ecocity_stations_about_city['id_station'].unique().tolist()
ecocity_stations_about_city_list
# Out:
# ['EcoCity_337',
#  'EcoCity_767',
#  'EcoCity_774',
#  'EcoCity_790',
#  'EcoCity_848',
#  'EcoCity_1315',
#  'EcoCity_1183',
#  'EcoCity_761']

# %%
stations_about = stations_about[~stations_about['id_station'].isin(ecocity_stations_about_city_list)]
stations_about
# Out:
#          id_station      lat      lng
# 2   SaveEcoBot_1008  49.2393  28.4799
# 3  SaveEcoBot_17796  49.2380  28.4820

# %%
stations_about = pd.concat([ecocity_stations_about_city, stations_about], ignore_index=True)
stations_about
# Out:
#          id_station      lat      lng
# 0       EcoCity_337  49.2267  28.5259
# 1       EcoCity_767  49.2329  28.4704
# 2       EcoCity_774  49.2455  28.4936
# 3       EcoCity_790  49.2268  28.4194
# 4       EcoCity_848  49.2307  28.4371
# 5      EcoCity_1315  49.2330  28.4100
# 6      EcoCity_1183  49.2311  28.4371
# 7       EcoCity_761  49.2222  28.4242
# 8   SaveEcoBot_1008  49.2393  28.4799
# 9  SaveEcoBot_17796  49.2380  28.4820

# %%
# Add data about stations of the Center for Hydrometeorology in Vinnytsia region (http://meteo.vn.ua/api/api.php)
# Source: https://www.vmr.gov.ua/Branches/Lists/Ecology/ShowContent.aspx?ID=24
num = len(stations_about)
stations_about.loc[num, 'id_station'] = 'VinnCHM_1'
stations_about.loc[num, 'lat'] = 49.241962 
stations_about.loc[num, 'lng'] = 28.478482
stations_about.loc[num+1, 'id_station'] = 'VinnCHM_2'
stations_about.loc[num+1, 'lat'] = 49.231392
stations_about.loc[num+1, 'lng'] = 28.518974
stations_about
# Out:
#           id_station        lat        lng
# 0        EcoCity_337  49.226700  28.525900
# 1        EcoCity_767  49.232900  28.470400
# 2        EcoCity_774  49.245500  28.493600
# 3        EcoCity_790  49.226800  28.419400
# 4        EcoCity_848  49.230700  28.437100
# 5       EcoCity_1315  49.233000  28.410000
# 6       EcoCity_1183  49.231100  28.437100
# 7        EcoCity_761  49.222200  28.424200
# 8    SaveEcoBot_1008  49.239300  28.479900
# 9   SaveEcoBot_17796  49.238000  28.482000
# 10         VinnCHM_1  49.241962  28.478482
# 11         VinnCHM_2  49.231392  28.518974

# %% [markdown]
# ## 3. Prediction<a class="anchor" id="3"></a>
#
# [Back to Table of Contents](#0.1)

# %%
stations_about_list = stations_about['id_station'].tolist()
stations_about_list
# Out:
# ['EcoCity_337',
#  'EcoCity_767',
#  'EcoCity_774',
#  'EcoCity_790',
#  'EcoCity_848',
#  'EcoCity_1315',
#  'EcoCity_1183',
#  'EcoCity_761',
#  'SaveEcoBot_1008',
#  'SaveEcoBot_17796',
#  'VinnCHM_1',
#  'VinnCHM_2']

# %%
st_par = pd.read_csv('../input/air-quality-monitoring/stations_parameters_prediction.csv', header=0, sep=';')
st_par
# Out:
#           id_station  PM2.5_k1  PM2.5_k0  PM2.5_a1  PM2.5_b1  PM10_k1  \
# 0        EcoCity_337         1         1         1         1        1
# 1        EcoCity_767         1         1         1         1        1
# 2        EcoCity_774         1         1         1         1        1
# 3        EcoCity_790         1         1         1         1        1
# 4        EcoCity_848         1         1         1         1        1
# 5       EcoCity_1315         1         1         1         1        1
# 6       EcoCity_1183         1         1         1         1        1
# 7        EcoCity_761         1         1         1         1        1
# 8    SaveEcoBot_1008         1         1         1         1        1
# 9   SaveEcoBot_17796         1         1         1         1        1
# 10         VinnCHM_2         1         1         1         1        1
# 11         VinnCHM_1         1         1         1         1        1
# 12         VinnCHM_2         1         1         1         1        1
#
#     PM10_k0  PM10_a1  PM10_b1
# 0         1        1        1
# 1         1        1        1
# 2         1        1        1
# 3         1        1        1
# 4         1        1        1
# 5         1        1        1
# 6         1        1        1
# 7         1        1        1
# 8         1        1        1
# 9         1        1        1
# 10        1        1        1
# 11        1        1        1
# 12        1        1        1

# %%
def f(st_par, id_station, indicator_name, t):
    # Prediction value of th indicator_name for the station with id_station 
    # in the time moment t by parameters from the st_par
    
    df = st_par[st_par['id_station']==id_station].reset_index(drop=True)
    k1 = float(df.loc[0, indicator_name+"_k1"])
    k0 = float(df.loc[0, indicator_name+"_k0"])
    a1 = float(df.loc[0, indicator_name+"_a1"])
    b1 = float(df.loc[0, indicator_name+"_b1"])
        
    return k0 + k1*t + a1*np.sin(t) + b1*np.cos(t)

# %%
res = pd.DataFrame(columns=['id_station', 't', 'y'])
res.loc[0,'t']=1

# %%
res = pd.DataFrame(columns=['id_station', 'indicator_name', 't', 'y'])
w = 0
for id_station in stations_about_list:
    for indicator_name in ['PM2.5', 'PM10']:
        for t in range(10):
            res.loc[w, 'id_station'] = id_station
            res.loc[w, 'indicator_name'] = indicator_name
            res.loc[w, 't'] = t
            res.loc[w, 'y'] = f(st_par, id_station, indicator_name, t) + np.random.normal(0, .1, 1)[0]
            w += 1

# %%
res
# Out:
#       id_station indicator_name  t         y
# 0    EcoCity_337          PM2.5  0  1.984141
# 1    EcoCity_337          PM2.5  1  3.450029
# 2    EcoCity_337          PM2.5  2  3.560624
# 3    EcoCity_337          PM2.5  3  3.107028
# 4    EcoCity_337          PM2.5  4  3.527677
# ..           ...            ... ..       ...
# 235    VinnCHM_2           PM10  5  5.184887
# 236    VinnCHM_2           PM10  6  7.761574
# 237    VinnCHM_2           PM10  7  9.343649
# 238    VinnCHM_2           PM10  8  9.797977
# 239    VinnCHM_2           PM10  9  9.500483
#
# [240 rows x 4 columns]

# %%
stations_about
# Out:
#           id_station        lat        lng
# 0        EcoCity_337  49.226700  28.525900
# 1        EcoCity_767  49.232900  28.470400
# 2        EcoCity_774  49.245500  28.493600
# 3        EcoCity_790  49.226800  28.419400
# 4        EcoCity_848  49.230700  28.437100
# 5       EcoCity_1315  49.233000  28.410000
# 6       EcoCity_1183  49.231100  28.437100
# 7        EcoCity_761  49.222200  28.424200
# 8    SaveEcoBot_1008  49.239300  28.479900
# 9   SaveEcoBot_17796  49.238000  28.482000
# 10         VinnCHM_1  49.241962  28.478482
# 11         VinnCHM_2  49.231392  28.518974

# %% [markdown]
# ## 4. Mapping<a class="anchor" id="4"></a>
#
# [Back to Table of Contents](#0.1)

# %%
m = folium.Map(location=[49.2355, 28.474], zoom_start=13, tiles="Stamen Terrain")

for i in range(len(stations_about)):
    marker = folium.Marker(
        location=[float(stations_about.loc[i, 'lat']), float(stations_about.loc[i, 'lng'])],
        popup=folium.Popup(max_width=450)
    )
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_607b15923a1e1815c65f1d5dd3464471 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_607b15923a1e1815c65f1d5dd3464471&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_607b15923a1e1815c65f1d5dd3464471 = L.map(
#                 &quot;map_607b15923a1e1815c65f1d5dd3464471&quot;,
#                 {
#                     center: [49.2355, 28.474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a47b68260338978b854ffe8466b2d740 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#             var marker_8bf5f98a67f3b93e9fcb236197578e13 = L.marker(
#                 [49.2267, 28.5259],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_a15b6acfa5fbcfaf12bbf79c4e354b9d = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_8bf5f98a67f3b93e9fcb236197578e13.bindPopup(popup_a15b6acfa5fbcfaf12bbf79c4e354b9d)
#         ;
#
#
#
#
#             var marker_61453bb1b83c9f6725f3c4b2df99976c = L.marker(
#                 [49.2329, 28.4704],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_84e6469a8751e01d3f9fbf0cc8d1885e = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_61453bb1b83c9f6725f3c4b2df99976c.bindPopup(popup_84e6469a8751e01d3f9fbf0cc8d1885e)
#         ;
#
#
#
#
#             var marker_f930b531131aeec47a5c068a496e1a41 = L.marker(
#                 [49.2455, 28.4936],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_bf1dad31179734bed5fd12fcc9e1203c = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_f930b531131aeec47a5c068a496e1a41.bindPopup(popup_bf1dad31179734bed5fd12fcc9e1203c)
#         ;
#
#
#
#
#             var marker_768f22a29bf11fa039dbef09abe3e7b4 = L.marker(
#                 [49.2268, 28.4194],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_23f275dcba4b550b54c4a33453a62885 = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_768f22a29bf11fa039dbef09abe3e7b4.bindPopup(popup_23f275dcba4b550b54c4a33453a62885)
#         ;
#
#
#
#
#             var marker_dddb32131b4dc11288475c47ebaaa6f0 = L.marker(
#                 [49.2307, 28.4371],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_5859d00cf60a2512b25010f6e528e022 = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_dddb32131b4dc11288475c47ebaaa6f0.bindPopup(popup_5859d00cf60a2512b25010f6e528e022)
#         ;
#
#
#
#
#             var marker_e0f3883c1e4a49a2fed4d497e172f602 = L.marker(
#                 [49.233, 28.41],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_c395ece6ba50bc5e8bcd3d4c5cf9fa04 = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_e0f3883c1e4a49a2fed4d497e172f602.bindPopup(popup_c395ece6ba50bc5e8bcd3d4c5cf9fa04)
#         ;
#
#
#
#
#             var marker_e079cc1118b08a5d56d279da04a28e2f = L.marker(
#                 [49.2311, 28.4371],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_3e29690f8f8ffe444207380da1bc2a54 = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_e079cc1118b08a5d56d279da04a28e2f.bindPopup(popup_3e29690f8f8ffe444207380da1bc2a54)
#         ;
#
#
#
#
#             var marker_fbfede4e20ef7253cad60fc523962040 = L.marker(
#                 [49.2222, 28.4242],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_96ec6c38ffa6a621e4a6fc68a70e261e = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_fbfede4e20ef7253cad60fc523962040.bindPopup(popup_96ec6c38ffa6a621e4a6fc68a70e261e)
#         ;
#
#
#
#
#             var marker_baa9c036d99e5417a5286b187605757e = L.marker(
#                 [49.2393, 28.4799],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd3464471);
#
#
#         var popup_232df04aa2fe2b3a60831b8793d846a5 = L.popup({&quot;maxWidth&quot;: 450});
#
#
#
#         marker_baa9c036d99e5417a5286b187605757e.bindPopup(popup_232df04aa2fe2b3a60831b8793d846a5)
#         ;
#
#
#
#
#             var marker_d7d5efe3daffeccddc6efde589f067d1 = L.marker(
#                 [49.238, 28.482],
#                 {}
#             ).addTo(map_607b15923a1e1815c65f1d5dd34

# %%
url = (
    "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data"
)
data = json.loads(requests.get(f"{url}/vis1.json").text)

m = folium.Map(location=[49.2355, 28.474], zoom_start=13)

for i in range(len(stations_about)):
    marker = folium.Marker(
        location=[float(stations_about.loc[i, 'lat']), float(stations_about.loc[i, 'lng'])],
        popup=folium.Popup(max_width=450).add_child(
            folium.Vega(data, width=450, height=450)   # Still need to replace data to res for given id_station and indicator 
        ),
    )
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-2.1.0.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b78eb742707ae9921ab20eae709df4c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_cf3c1b46280427449a8925524ec3d69e {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_cb6a0600def50657111357a613a08db5 {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_6e3ce18c5a37f8deac9654491bfbb6b6 {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_bf48a84e7c6cb9b8070dd92d200bdb8e {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_6f11a1d9cea46cbce17ef7d0144a2993 {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_67261d4924e2933482e273243b1b27ff {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_9295abd39fc438f455f7d1d64ab5a6b0 {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_4eceff804ce95c688be35b3e7e4badad {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_101061c5be17af08eee9d34659ab41cc {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_e2a49c32ec625c72b538bb532c08b3a2 {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_e78867ea7d9eef5bbd58d5b69d31da4e {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_0bd73b9d94d8d6bd0de4a138995115bf {
#                 position : relative;
#                 width : 450.0px;
#                 height: 450.0px;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b78eb742707ae9921ab20eae709df4c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b78eb742707ae9921ab20eae709df4c0 = L.map(
#                 &quot;map_b78eb742707ae9921ab20eae709df4c0&quot;,
#                 {
#                     center: [49.2355, 28.474],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_827f5f22e36bb2376690bb2a908ed4ae = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b78eb742707ae9921ab20eae709df4c0);
#
#
#             var marker_5388ef6684d9d929e46c0df5a190d704 = L.marker(
#                 [49.2267, 28.5259],
#                 {}
#             ).addTo(map_b78eb742707ae9921ab20eae709df4c0);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_ee6c091c262060c1bd7a69a5459f5f3c = L.popup({&quot;maxWidth&quot;: 450});
#
#
#             var vega_cf3c1b46280427449a8925524ec3d69e = $(`             &lt;div id=&quot;vega_cf3c1b46280427449a8925524ec3d69e&quot;&gt;&lt;/div&gt;             `)[0];
#             popup_ee6c091c262060c1bd7a69a5459f5f3c.setContent(vega_cf3c1b46280427449a8925524ec3d69e);
#
#
#         marker_5388ef6684d9d929e46c0df5a190d704.bindPopup(popup_ee6c091c2

# %% [markdown]
# I hope you find this notebook useful and enjoyable.
#
# Your comments and feedback are most welcome.
#
# [Go to Top](#0)
